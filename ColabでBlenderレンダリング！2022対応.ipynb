# %% [markdown]
# # 使い方
# Google DriveにレンダリングしたいBlendファイルを入れてください。
# 使いすぎるとColabの利用制限でGPUが一定時間使えなくかもしれないので注意を。
# GPUガチャあります。当たりはめっちゃ早いです。ハズレは、早いけどーって感じです。K80はハズレ、T2などはめっちゃ早いです。多分、アメリカらへんが夜中のときはT2割当が多くなる気がします。
#
# 入力し終わったら、ランタイムから全てのセルを実行を選択すると処理が始まります。
#
# 参考にみたサイト
#
# https://microsingularity.github.io/blog/Blender-Colab
#
# https://colab.research.google.com/github/ynshung/blender-colab/blob/master/blender_render.ipynb

# %%
# GPU確認
# !nvidia-smi
# Out:
# Thu Apr 14 03:00:24 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#Google Driveと連携する
from google.colab import drive
drive.mount('/drive/')
# Out:
# Mounted at /drive/

# %%
#Blender3.01(Linux版をダウンロード)
# !wget -nc https://ftp.nluug.nl/pub/graphics/blender/release/Blender3.0/blender-3.0.1-linux-x64.tar.xz
# Out:
# --2022-04-14 03:00:41--  https://ftp.nluug.nl/pub/graphics/blender/release/Blender3.0/blender-3.0.1-linux-x64.tar.xz
# Resolving ftp.nluug.nl (ftp.nluug.nl)... 145.220.21.40, 2001:67c:6ec:221:145:220:21:40
# Connecting to ftp.nluug.nl (ftp.nluug.nl)|145.220.21.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 186027304 (177M) [application/x-tar]
# Saving to: ‘blender-3.0.1-linux-x64.tar.xz’
#
# blender-3.0.1-linux 100%[===================>] 177.41M  6.17MB/s    in 34s
#
# 2022-04-14 03:01:16 (5.28 MB/s) - ‘blender-3.0.1-linux-x64.tar.xz’ saved [186027304/186027304]

# %%
#ダウンロードしたやつを解凍
# !tar xf blender-3.0.1-linux-x64.tar.xz

# %%
#MyDriveの後に、レンダリングしたいBlendファイルを指定
Filepath = "blender3d/untitled.blend"#@param {type:"string"}
filename = '/drive/MyDrive/' + Filepath

# %%
#デフォルトのlibtcmalloc-minimal4バージョンを削除して、Ubuntuのデフォルトバージョンをインストールする
#下のコードがうまく動かないときに動かす
import os

os.environ["LD_PRELOAD"] = ""

#Deletes wrong Version of libtcmalloc-minimal4
# !apt remove libtcmalloc-minimal4
#Installs correct version of libtcmalloc-minimal4
# !apt install libtcmalloc-minimal4

#Adds this library to the user environment
os.environ["LD_PRELOAD"] = "/usr/lib/x86_64-linux-gnu/libtcmalloc_minimal.so.4.3.0"
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages will be REMOVED:
#   google-perftools libgoogle-perftools4 libtcmalloc-minimal4
# 0 upgraded, 0 newly installed, 3 to remove and 39 not upgraded.
# After this operation, 2,187 kB disk space will be freed.
# (Reading database ... 155455 files and directories currently installed.)
# Removing google-perftools (2.5-2.2ubuntu3) ...
# Removing libgoogle-perftools4 (2.5-2.2ubuntu3) ...
# Removing libtcmalloc-minimal4 (2.5-2.2ubuntu3) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   libtcmalloc-minimal4
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 91.6 kB of archives.
# After this operation, 380 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtcmalloc-minimal4 amd64 2.5-2.2ubuntu3 [91.6 kB]
# Fetched 91.6 kB in 1s (103 kB/s)
# Selecting previously unselected package libtcmalloc-minimal4.
# (Reading database ... 155381 files and directories currently installed.)
# Preparing to unpack .../libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libtcmalloc-minimal4 (2.5-2.2ubuntu3) ...
# Setting up libtcmalloc-minimal4 (2.5-2.2ubuntu3) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
#レンダリングしたものは、指定されたGoogle Driveのパスに保存されます。（Linuxのフォルダに何故か保存されるときもある）
RenderingOutputPath = "blender3d"#@param {type:"string"}
# --debug-all -o "/drive/MyDrive/" + RenderingOutputPath
RenderPath = '/drive/MyDrive/' + RenderingOutputPath
animation = False #@param {type:"boolean"}

#写真をレンダリング
# !./blender-3.0.1-linux-x64/blender -b $filename -noaudio -E 'CYCLES' --debug-all -o '{RenderPath}' -f 1 -F 'PNG' -- --cycles-device CUDA

#アニメーションをレンダリング
# !./blender-3.0.1-linux-x64/blender -b $filename -noaudio -E 'CYCLES' -o /drive/MyDrive/3d/ -s 1 -e 280 -a -- --cycles-device CUDA
#アニメーションをレンダリングするときは、上の写真をモデリングのコードをコメントアウトして
#アニメーションをレンダリングの下にあるコードをコメントアウトの解除をする。
# Out:
# Switching to fully guarded memory allocator.
# Blender 3.0.1 (hash dc2d18018171 built 2022-01-26 00:40:57)
# graph_id_tag_update: id=SCScene flags=LEGACY_0 source=USER_EDIT
# graph_id_tag_update: id=GRScene Collection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GROVERRIDE_RESYNC_LEFTOVERS flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRScene Collection flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRScene Collection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GROVERRIDE_RESYNC_LEFTOVERS flags=COPY_ON_WRITE source=USER_EDIT
# DEG_relations_tag_update: Tagging relations for update.
# graph_id_tag_update: id=GRScene Collection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GROVERRIDE_RESYNC_LEFTOVERS flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRScene Collection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GROVERRIDE_RESYNC_LEFTOVERS flags=COPY_ON_WRITE source=USER_EDIT
# DEG_relations_tag_update: Tagging relations for update.
# ED_screen_refresh: set screen
# time bl_operators 0.0850
# time bl_ui 0.3686
# time keyingsets_builtins 0.0049
# time nodeitems_builtins 0.0119
# bl_app_template_utils.reset('')
# 	addon_utils.enable io_anim_bvh
# 	addon_utils.enable io_curve_svg
# 	addon_utils.enable io_mesh_ply
# 	addon_utils.enable io_mesh_stl
# 	addon_utils.enable io_mesh_uv_layout
# 	addon_utils.enable io_scene_fbx
# 	addon_utils.enable io_scene_gltf2
# 	addon_utils.enable io_scene_obj
# 	addon_utils.enable io_scene_x3d
# 	addon_utils.enable cycles
# 	addon_utils.enable pose_library
# Python Script Load Time 0.7124
# Warning, unregistered class: ViewLayerAOVPanel(Panel)
# Warning, unregistered class: ViewLayerCryptomattePanel(Panel)
# Warning, unregistered class: CyclesPresetPanel(Panel)
# [SCScene :: ViewLayer]: Removed 24 relations to no-op nodes
# graph_id_tag_update: id=SCScene flags=TRANSFORM, GEOMETRY, SHADING, SELECT, BASE_FLAGS, POINT_CACHE, COPY_ON_WRITE, SEQUENCER_STRIPS, AUDIO_SEEK, AUDIO_FPS, AUDIO_VOLUME, AUDIO_MUTE, AUDIO_LISTENER, AUDIO, PARAMETERS, TAG_FOR_UNDO source=RELATIONS
# graph_id_tag_update: id=OBCube flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=MECube flags=LEGACY_0 source=RELATIONS
# graph_id_tag_update: id=MECube flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=MAMaterial flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=OBLight flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=LALight flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=OBCamera flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=CACamera flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=GRScene Collection flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=WOWorld flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=LSLineStyle flags=COPY_ON_WRITE source=RELATIONS
# Depsgraph built in 0.000392 seconds.
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=OBCube flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=MECube flags=LEGACY_0 source=VISIBILITY
# graph_id_tag_update: id=MECube flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=MAMaterial flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=OBLight flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=LALight flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=OBCamera flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=CACamera flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=GRScene Collection flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=WOWorld flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=LSLineStyle flags=COPY_ON_WRITE source=VISIBILITY
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: SOUND_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_FINAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_LOCAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL_DONE()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: AUDIO_VOLUME()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_SELECT_UPDATE()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_SIMULATION_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_FINAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: SEQUENCES_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: SCENE_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_FINAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_SIMULATION_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_ENTRY()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: VIEW_LAYER_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_LOCAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: OPERATION()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_EXIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_SIMULATION_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_ENTRY()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_LOCAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_EXIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL_DONE()
# [SCScene :: ViewLayer]: Operation is entry point for update: AUDIO_ENTRY()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: OPERATION()
# [SCScene :: ViewLayer]: Accumulated recalc bits for SCScene: 4286574467
# [SCScene :: ViewLayer]: Accumulated recalc bits for OBCube: 8323
# [SCScene :: ViewLayer]: Accumulated recalc bits for MECube: 4286574467
# [SCScene :: ViewLayer]: Accumulated recalc bits for MAMaterial: 8320
# [SCScene :: ViewLayer]: Accumulated recalc bits for NTShader Nodetree: 8320
# [SCScene :: ViewLayer]: Accumulated recalc bits for OBLight: 8195
# [SCScene :: ViewLayer]: Accumulated recalc bits for LALight: 8320
# [SCScene :: ViewLayer]: Accumulated recalc bits for OBCamera: 8195
# [SCScene :: ViewLayer]: Accumulated recalc bits for CACamera: 8192
# [SCScene :: ViewLayer]: Accumulated recalc bits for GRScene Collection: 8195
# [SCScene :: ViewLayer]: Accumulated recalc bits for GRCollection: 8192
# [SCScene :: ViewLayer]: Accumulated recalc bits for WOWorld: 8320
# [SCScene :: ViewLayer]: Accumulated recalc bits for NTShader Nodetree: 8320
# [SCScene :: ViewLayer]: Accumulated recalc bits for LSLineStyle: 8192
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on LSLineStyle (0x7f65582e07b8)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on NTShader Nodetree (0x7f65582e02b8)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on WOWorld (0x7f65582e5f38)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on GRCollection (0x7f65582e54b8)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on GRScene Collection (0x7f655829f2b8)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on CACamera (0x7f65585143b8)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on OBCamera (0x7f6558292638)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on LALight (0x7f655a433638)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on OBLight (0x7f655a684838)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on NTShader Nodetree (0x7f6558514138)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on MAMaterial (0x7f655a5892b8)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on MECube (0x7f655a42e838)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on OBCube (0x7f655a684e38)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on SCScene (0x7f6560d51438)
# [SCScene :: ViewLayer]: layer_eval_view_layer on ViewLayer (0x7f65582e7d38)
# [SCScene :: ViewLayer]: BKE_object_eval_eval_base_flags on OBCamera (0x7f6558292638)
# [SCScene :: ViewLayer]: BKE_object_eval_eval_base_flags on OBLight (0x7f655a684838)
# [SCScene :: ViewLayer]: BKE_object_eval_eval_base_flags on OBCube (0x7f655a684e38)
# [SCScene :: ViewLayer]: SEQ_eval_sequences on SCScene (0x7f6560d51438)
# [SCScene :: ViewLayer]: BKE_world_eval on WOWorld (0x7f65582e5f38)
# [SCScene :: ViewLayer]: BKE_object_eval_local_transform on OBCamera (0x7f6558292638)
# [SCScene :: ViewLayer]: BKE_object_eval_transform_final on OBCamera (0x7f6558292638)
# [SCScene :: ViewLayer]: BKE_light_eval on LALight (0x7f655a433638)
# [SCScene :: ViewLayer]: BKE_object_eval_local_transform on OBLight (0x7f655a684838)
# [SCScene :: ViewLayer]: BKE_object_eval_transform_final on OBLight (0x7f655a684838)
# [SCScene :: ViewLayer]: BKE_material_eval on MAMaterial (0x7f655a5892b8)
# [SCScene :: ViewLayer]: BKE_object_data_select_update on MECube (0x7f655a42e838)
# [SCScene :: ViewLayer]: BKE_mesh_eval_geometry on MECube (0x7f655a42e838)
# [SCScene :: ViewLayer]: BKE_object_eval_uber_data on OBCube (0x7f655a684e38)
# [SCScene :: ViewLayer]: BKE_object_handle_data_update on OBCube (0x7f655a684e38)
# [SCScene :: ViewLayer]: BKE_object_select_update on OBCube (0x7f655a684e38)
# [SCScene :: ViewLayer]: BKE_object_data_select_update on MECube (0x7f655a5ed838)
# [SCScene :: ViewLayer]: BKE_object_eval_local_transform on OBCube (0x7f655a684e38)
# [SCScene :: ViewLayer]: BKE_object_eval_transform_final on OBCube (0x7f655a684e38)
# Depsgraph updated in 0.000561 seconds.
# Depsgraph evaluation FPS: -nan
# FRS_set_context: context 0x0x7f6563465b58 scene 0x0x7f655a15e038
# Read blend: /drive/MyDrive/blender3d/untitled.blend
# graph_id_tag_update: id=GRScene Collection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GROVERRIDE_RESYNC_LEFTOVERS flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRScene Collection flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRScene Collection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GROVERRIDE_RESYNC_LEFTOVERS flags=COPY_ON_WRITE source=USER_EDIT
# DEG_relations_tag_update: Tagging relations for update.
# graph_id_tag_update: id=GRScene Collection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GROVERRIDE_RESYNC_LEFTOVERS flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRScene Collection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=GROVERRIDE_RESYNC_LEFTOVERS flags=COPY_ON_WRITE source=USER_EDIT
# DEG_relations_tag_update: Tagging relations for update.
# DEG_relations_tag_update: Tagging relations for update.
# ED_screen_refresh: set screen
# [SCScene :: ViewLayer]: Removed 30 relations to no-op nodes
# graph_id_tag_update: id=SCScene flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=OBCube flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=MECube flags=LEGACY_0 source=RELATIONS
# graph_id_tag_update: id=MECube flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=MAMaterial flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=OBLight flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=LALight flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=OBCamera flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=CACamera flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=OB平面 flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=ME平面 flags=LEGACY_0 source=RELATIONS
# graph_id_tag_update: id=ME平面 flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=GRScene Collection flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=WOWorld flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=LSLineStyle flags=COPY_ON_WRITE source=RELATIONS
# Depsgraph built in 0.000248 seconds.
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=OBCube flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=MECube flags=LEGACY_0 source=VISIBILITY
# graph_id_tag_update: id=MECube flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=MAMaterial flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=OBLight flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=LALight flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=OBCamera flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=CACamera flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=OB平面 flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=ME平面 flags=LEGACY_0 source=VISIBILITY
# graph_id_tag_update: id=ME平面 flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=GRScene Collection flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=WOWorld flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=LSLineStyle flags=COPY_ON_WRITE source=VISIBILITY
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: AUDIO_VOLUME()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_LOCAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_SIMULATION_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_EXIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_FINAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_FINAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: VIEW_LAYER_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_SIMULATION_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_ENTRY()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL_DONE()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: OPERATION()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_EXIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_EXIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL_DONE()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_SIMULATION_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_SELECT_UPDATE()
# [SCScene :: ViewLayer]: Operation is entry point for update: OPERATION()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_SIMULATION_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_FINAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: OPERATION()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL_DONE()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_SELECT_UPDATE()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_LOCAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_LOCAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_FINAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: AUDIO_ENTRY()
# [SCScene :: ViewLayer]: Operation is entry point for update: SCENE_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL_INIT()
# [SCScene :: ViewLayer]: Operation is entry point for update: SEQUENCES_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_ENTRY()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: PARAMETERS_ENTRY()
# [SCScene :: ViewLayer]: Operation is entry point for update: SOUND_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_LOCAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: COPY_ON_WRITE()
# [SCScene :: ViewLayer]: Operation is entry point for update: TRANSFORM_EVAL()
# [SCScene :: ViewLayer]: Operation is entry point for update: GEOMETRY_EVAL()
# [SCScene :: ViewLayer]: Accumulated recalc bits for SCScene: 8195
# [SCScene :: ViewLayer]: Accumulated recalc bits for OBCube: 8323
# [SCScene :: ViewLayer]: Accumulated recalc bits for MECube: 4286574467
# [SCScene :: ViewLayer]: Accumulated recalc bits for MAMaterial: 8320
# [SCScene :: ViewLayer]: Accumulated recalc bits for NTShader Nodetree: 8320
# [SCScene :: ViewLayer]: Accumulated recalc bits for OBLight: 8195
# [SCScene :: ViewLayer]: Accumulated recalc bits for LALight: 8320
# [SCScene :: ViewLayer]: Accumulated recalc bits for OBCamera: 8195
# [SCScene :: ViewLayer]: Accumulated recalc bits for CACamera: 8192
# [SCScene :: ViewLayer]: Accumulated recalc bits for OB平面: 8323
# [SCScene :: ViewLayer]: Accumulated recalc bits for ME平面: 4286574467
# [SCScene :: ViewLayer]: Accumulated recalc bits for GRScene Collection: 8195
# [SCScene :: ViewLayer]: Accumulated recalc bits for GRCollection: 8192
# [SCScene :: ViewLayer]: Accumulated recalc bits for WOWorld: 8320
# [SCScene :: ViewLayer]: Accumulated recalc bits for NTShader Nodetree: 8320
# [SCScene :: ViewLayer]: Accumulated recalc bits for LSLineStyle: 8192
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on LSLineStyle (0x7f655a29ec38)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on NTShader Nodetree (0x7f655a29f138)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on WOWorld (0x7f655829e238)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on GRCollection (0x7f655829d638)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on GRScene Collection (0x7f6558268bb8)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on ME平面 (0x7f655a181838)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on SCScene (0x7f655a15e038)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on OB平面 (0x7f655a20b238)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on MECube (0x7f655a181038)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on CACamera (0x7f655a2a0538)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on OBCamera (0x7f655a20b838)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on LALight (0x7f655a1a1638)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on OBLight (0x7f655a20be38)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on NTShader Nodetree (0x7f655a2a07b8)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on OBCube (0x7f65585d2c38)
# [SCScene :: ViewLayer]: deg_evaluate_copy_on_write on MAMaterial (0x7f655a179f78)
# [SCScene :: ViewLayer]: BKE_object_eval_local_transform on OBCube (0x7f65585d2c38)
# [SCScene :: ViewLayer]: layer_eval_view_layer on ViewLayer (0x7f65582f94b8)
# [SCScene :: ViewLayer]: BKE_object_eval_transform_final on OBCube (0x7f65585d2c38)
# [SCScene :: ViewLayer]: BKE_object_eval_eval_base_flags on OB平面 (0x7f655a20b238)
# [SCScene :: ViewLayer]: BKE_mesh_eval_geometry on MECube (0x7f655a181038)
# [SCScene :: ViewLayer]: BKE_object_eval_eval_base_flags on OBCamera (0x7f655a20b838)
# [SCScene :: ViewLayer]: BKE_object_eval_eval_base_flags on OBLight (0x7f655a20be38)
# [SCScene :: ViewLayer]: BKE_object_eval_eval_base_flags on OBCube (0x7f65585d2c38)
# [SCScene :: ViewLayer]: BKE_object_eval_uber_data on OBCube (0x7f65585d2c38)
# [SCScene :: ViewLayer]: BKE_object_handle_data_update on OBCube (0x7f65585d2c38)
# [SCScene :: ViewLayer]: SEQ_eval_sequences on SCScene (0x7f655a15e038)
# [SCScene :: ViewLayer]: BKE_world_eval on WOWorld (0x7f655829e238)
# [SCScene :: ViewLayer]: BKE_object_data_select_update on ME平面 (0x7f655a181838)
# [SCScene :: ViewLayer]: BKE_mesh_eval_geometry on ME平面 (0x7f655a181838)
# [SCScene :: ViewLayer]: BKE_object_eval_uber_data on OB平面 (0x7f655a20b238)
# [SCScene :: ViewLayer]: BKE_object_handle_data_update on OB平面 (0x7f655a20b238)
# [SCScene :: ViewLayer]: BKE_object_select_update on OB平面 (0x7f655a20b238)
# [SCScene :: ViewLayer]: BKE_object_data_select_update on ME平面 (0x7f655a5ed838)
# [SCScene :: ViewLayer]: BKE_object_data_select_update on MECube (0x7f655a181038)
# [SCScene :: ViewLayer]: BKE_object_eval_local_transform on OB平面 (0x7f655a20b238)
# [SCScene :: ViewLayer]: BKE_object_select_update on OBCube (0x7f65585d2c38)
# [SCScene :: ViewLayer]: BKE_object_data_select_update on MECube (0x7f6555a32838)
# [SCScene :: ViewLayer]: BKE_object_eval_transform_final on OB平面 (0x7f655a20b238)
# [SCScene :: ViewLayer]: BKE_material_eval on MAMaterial (0x7f655a179f78)
# [SCScene :: ViewLayer]: BKE_object_eval_local_transform on OBCamera (0x7f655a20b838)
# [SCScene :: ViewLayer]: BKE_object_eval_local_transform on OBLight (0x7f655a20be38)
# [SCScene :: ViewLayer]: BKE_object_eval_transform_final on OBCamera (0x7f655a20b838)
# [SCScene :: ViewLayer]: BKE_light_eval on LALight (0x7f655a1a1638)
# [SCScene :: ViewLayer]: BKE_object_eval_transform_final on OBLight (0x7f655a20be38)
# Depsgraph updated in 0.000438 seconds.
# Depsgraph evaluation FPS: -nan
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# [RENDER PIPELINE]: Removed 15 relations to no-op nodes
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=OBCamera flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=CACamera flags=COPY_ON_WRITE source=RELATIONS
# Depsgraph built in 0.000076 seconds.
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=OBCamera flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=CACamera flags=COPY_ON_WRITE source=VISIBILITY
# [RENDER PIPELINE]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER PIPELINE]: Operation is entry point for update: TRANSFORM_LOCAL()
# [RENDER PIPELINE]: Operation is entry point for update: SOUND_EVAL()
# [RENDER PIPELINE]: Operation is entry point for update: PARAMETERS_EXIT()
# [RENDER PIPELINE]: Operation is entry point for update: OPERATION()
# [RENDER PIPELINE]: Operation is entry point for update: TRANSFORM_INIT()
# [RENDER PIPELINE]: Operation is entry point for update: SEQUENCES_EVAL()
# [RENDER PIPELINE]: Operation is entry point for update: AUDIO_VOLUME()
# [RENDER PIPELINE]: Operation is entry point for update: SCENE_EVAL()
# [RENDER PIPELINE]: Operation is entry point for update: PARAMETERS_ENTRY()
# [RENDER PIPELINE]: Operation is entry point for update: TRANSFORM_EVAL()
# [RENDER PIPELINE]: Operation is entry point for update: TRANSFORM_SIMULATION_INIT()
# [RENDER PIPELINE]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER PIPELINE]: Operation is entry point for update: TRANSFORM_FINAL()
# [RENDER PIPELINE]: Operation is entry point for update: AUDIO_ENTRY()
# [RENDER PIPELINE]: Operation is entry point for update: PARAMETERS_EVAL()
# [RENDER PIPELINE]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER PIPELINE]: Accumulated recalc bits for SCScene: 8192
# [RENDER PIPELINE]: Accumulated recalc bits for OBCamera: 8195
# [RENDER PIPELINE]: Accumulated recalc bits for CACamera: 8192
# [RENDER PIPELINE]: deg_evaluate_copy_on_write on CACamera (0x7f65582c03b8)
# [RENDER PIPELINE]: deg_evaluate_copy_on_write on OBCamera (0x7f6558292638)
# [RENDER PIPELINE]: deg_evaluate_copy_on_write on SCScene (0x7f6560d51438)
# [RENDER PIPELINE]: SEQ_eval_sequences on SCScene (0x7f6560d51438)
# [RENDER PIPELINE]: BKE_object_eval_local_transform on OBCamera (0x7f6558292638)
# [RENDER PIPELINE]: BKE_object_eval_transform_final on OBCamera (0x7f6558292638)
# Depsgraph updated in 0.000093 seconds.
# Depsgraph evaluation FPS: -nan
# [RENDER]: Removed 30 relations to no-op nodes
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=OBCube flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=MECube flags=LEGACY_0 source=RELATIONS
# graph_id_tag_update: id=MECube flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=MAMaterial flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=OBLight flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=LALight flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=OBCamera flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=CACamera flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=OB平面 flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=ME平面 flags=LEGACY_0 source=RELATIONS
# graph_id_tag_update: id=ME平面 flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=GRScene Collection flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=WOWorld flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=RELATIONS
# graph_id_tag_update: id=LSLineStyle flags=COPY_ON_WRITE source=RELATIONS
# Depsgraph built in 0.072127 seconds.
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=OBCube flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=MECube flags=LEGACY_0 source=VISIBILITY
# graph_id_tag_update: id=MECube flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=MAMaterial flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=OBLight flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=LALight flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=OBCamera flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=CACamera flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=OB平面 flags=TRANSFORM, GEOMETRY, COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=ME平面 flags=LEGACY_0 source=VISIBILITY
# graph_id_tag_update: id=ME平面 flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=GRScene Collection flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=GRCollection flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=WOWorld flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=NTShader Nodetree flags=COPY_ON_WRITE source=VISIBILITY
# graph_id_tag_update: id=LSLineStyle flags=COPY_ON_WRITE source=VISIBILITY
# [RENDER]: Operation is entry point for update: GEOMETRY_EVAL()
# [RENDER]: Operation is entry point for update: OPERATION()
# [RENDER]: Operation is entry point for update: OPERATION()
# [RENDER]: Operation is entry point for update: GEOMETRY_EVAL_DONE()
# [RENDER]: Operation is entry point for update: TRANSFORM_INIT()
# [RENDER]: Operation is entry point for update: SEQUENCES_EVAL()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: TRANSFORM_INIT()
# [RENDER]: Operation is entry point for update: PARAMETERS_EXIT()
# [RENDER]: Operation is entry point for update: PARAMETERS_EXIT()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: GEOMETRY_SELECT_UPDATE()
# [RENDER]: Operation is entry point for update: TRANSFORM_LOCAL()
# [RENDER]: Operation is entry point for update: TRANSFORM_LOCAL()
# [RENDER]: Operation is entry point for update: TRANSFORM_INIT()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: GEOMETRY_SELECT_UPDATE()
# [RENDER]: Operation is entry point for update: AUDIO_VOLUME()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: TRANSFORM_EVAL()
# [RENDER]: Operation is entry point for update: TRANSFORM_FINAL()
# [RENDER]: Operation is entry point for update: TRANSFORM_LOCAL()
# [RENDER]: Operation is entry point for update: PARAMETERS_EXIT()
# [RENDER]: Operation is entry point for update: TRANSFORM_EVAL()
# [RENDER]: Operation is entry point for update: TRANSFORM_FINAL()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: TRANSFORM_INIT()
# [RENDER]: Operation is entry point for update: PARAMETERS_EVAL()
# [RENDER]: Operation is entry point for update: GEOMETRY_EVAL()
# [RENDER]: Operation is entry point for update: SOUND_EVAL()
# [RENDER]: Operation is entry point for update: OPERATION()
# [RENDER]: Operation is entry point for update: TRANSFORM_EVAL()
# [RENDER]: Operation is entry point for update: PARAMETERS_ENTRY()
# [RENDER]: Operation is entry point for update: TRANSFORM_SIMULATION_INIT()
# [RENDER]: Operation is entry point for update: TRANSFORM_LOCAL()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: TRANSFORM_SIMULATION_INIT()
# [RENDER]: Operation is entry point for update: TRANSFORM_SIMULATION_INIT()
# [RENDER]: Operation is entry point for update: GEOMETRY_EVAL()
# [RENDER]: Operation is entry point for update: GEOMETRY_EVAL_DONE()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: AUDIO_ENTRY()
# [RENDER]: Operation is entry point for update: TRANSFORM_FINAL()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: TRANSFORM_SIMULATION_INIT()
# [RENDER]: Operation is entry point for update: PARAMETERS_ENTRY()
# [RENDER]: Operation is entry point for update: TRANSFORM_FINAL()
# [RENDER]: Operation is entry point for update: TRANSFORM_EVAL()
# [RENDER]: Operation is entry point for update: VIEW_LAYER_EVAL()
# [RENDER]: Operation is entry point for update: GEOMETRY_EVAL_INIT()
# [RENDER]: Operation is entry point for update: PARAMETERS_EVAL()
# [RENDER]: Operation is entry point for update: GEOMETRY_EVAL_INIT()
# [RENDER]: Operation is entry point for update: GEOMETRY_EVAL()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: PARAMETERS_ENTRY()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: PARAMETERS_EVAL()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Operation is entry point for update: SCENE_EVAL()
# [RENDER]: Operation is entry point for update: COPY_ON_WRITE()
# [RENDER]: Accumulated recalc bits for SCScene: 8192
# [RENDER]: Accumulated recalc bits for OBCube: 8323
# [RENDER]: Accumulated recalc bits for MECube: 4286574467
# [RENDER]: Accumulated recalc bits for MAMaterial: 8320
# [RENDER]: Accumulated recalc bits for NTShader Nodetree: 8320
# [RENDER]: Accumulated recalc bits for OBLight: 8195
# [RENDER]: Accumulated recalc bits for LALight: 8320
# [RENDER]: Accumulated recalc bits for OBCamera: 8195
# [RENDER]: Accumulated recalc bits for CACamera: 8192
# [RENDER]: Accumulated recalc bits for OB平面: 8323
# [RENDER]: Accumulated recalc bits for ME平面: 4286574467
# [RENDER]: Accumulated recalc bits for GRScene Collection: 8192
# [RENDER]: Accumulated recalc bits for GRCollection: 8192
# [RENDER]: Accumulated recalc bits for WOWorld: 8320
# [RENDER]: Accumulated recalc bits for NTShader Nodetree: 8320
# [RENDER]: Accumulated recalc bits for LSLineStyle: 8192
# [RENDER]: deg_evaluate_copy_on_write on LSLineStyle (0x7f65585c1538)
# [RENDER]: deg_evaluate_copy_on_write on NTShader Nodetree (0x7f65585c1038)
# [RENDER]: deg_evaluate_copy_on_write on WOWorld (0x7f655a1a9a38)
# [RENDER]: deg_evaluate_copy_on_write on GRCollection (0x7f655a1a8fb8)
# [RENDER]: deg_evaluate_copy_on_write on GRScene Collection (0x7f655a1a8538)
# [RENDER]: deg_evaluate_copy_on_write on ME平面 (0x7f655858f038)
# [RENDER]: deg_evaluate_copy_on_write on OB平面 (0x7f655a20a638)
# [RENDER]: deg_evaluate_copy_on_write on CACamera (0x7f6558513c38)
# [RENDER]: deg_evaluate_copy_on_write on OBCamera (0x7f655a20ac38)
# [RENDER]: deg_evaluate_copy_on_write on LALight (0x7f655a28f838)
# [RENDER]: deg_evaluate_copy_on_write on OBLight (0x7f655a684e38)
# [RENDER]: deg_evaluate_copy_on_write on NTShader Nodetree (0x7f65582c0db8)
# [RENDER]: deg_evaluate_copy_on_write on MAMaterial (0x7f655a17b478)
# [RENDER]: deg_evaluate_copy_on_write on MECube (0x7f655a59b838)
# [RENDER]: deg_evaluate_copy_on_write on SCScene (0x7f655a161838)
# [RENDER]: deg_evaluate_copy_on_write on OBCube (0x7f655a684838)
# [RENDER]: BKE_object_eval_local_transform on OBCube (0x7f655a684838)
# [RENDER]: BKE_object_eval_transform_final on OBCube (0x7f655a684838)
# [RENDER]: BKE_mesh_eval_geometry on MECube (0x7f655a59b838)
# [RENDER]: BKE_object_data_select_update on MECube (0x7f655a59b838)
# [RENDER]: BKE_material_eval on MAMaterial (0x7f655a17b478)
# [RENDER]: BKE_object_eval_local_transform on OBLight (0x7f655a684e38)
# [RENDER]: BKE_object_eval_transform_final on OBLight (0x7f655a684e38)
# [RENDER]: BKE_light_eval on LALight (0x7f655a28f838)
# [RENDER]: BKE_object_eval_local_transform on OBCamera (0x7f655a20ac38)
# [RENDER]: BKE_object_eval_transform_final on OBCamera (0x7f655a20ac38)
# [RENDER]: BKE_object_eval_local_transform on OB平面 (0x7f655a20a638)
# [RENDER]: BKE_object_eval_transform_final on OB平面 (0x7f655a20a638)
# [RENDER]: layer_eval_view_layer on ViewLayer (0x7f655a1abb38)
# [RENDER]: BKE_object_eval_uber_data on OBCube (0x7f655a684838)
# [RENDER]: BKE_object_handle_data_update on OBCube (0x7f655a684838)
# [RENDER]: BKE_mesh_eval_geometry on ME平面 (0x7f655858f038)
# [RENDER]: BKE_object_eval_uber_data on OB平面 (0x7f655a20a638)
# [RENDER]: BKE_object_handle_data_update on OB平面 (0x7f655a20a638)
# [RENDER]: BKE_object_select_update on OBCube (0x7f655a684838)
# [RENDER]: BKE_object_data_select_update on MECube (0x7f6558567038)
# [RENDER]: BKE_object_eval_eval_base_flags on OB平面 (0x7f655a20a638)
# [RENDER]: BKE_object_eval_eval_base_flags on OBCamera (0x7f655a20ac38)
# [RENDER]: BKE_object_eval_eval_base_flags on OBLight (0x7f655a684e38)
# [RENDER]: BKE_object_data_select_update on ME平面 (0x7f655858f038)
# [RENDER]: BKE_object_select_update on OB平面 (0x7f655a20a638)
# [RENDER]: BKE_object_data_select_update on ME平面 (0x7f6555a33838)
# [RENDER]: BKE_world_eval on WOWorld (0x7f655a1a9a38)
# [RENDER]: SEQ_eval_sequences on SCScene (0x7f655a161838)
# [RENDER]: BKE_object_eval_eval_base_flags on OBCube (0x7f655a684838)
# Depsgraph updated in 0.002352 seconds.
# Depsgraph evaluation FPS: -nan
# I0414 03:01:49.107487   626 device.cpp:45] CUEW initialization succeeded
# I0414 03:01:49.107548   626 device.cpp:47] Found precompiled kernels
# I0414 03:01:49.163734   626 device.cpp:194] Device has compute preemption or is not used for display.
# I0414 03:01:49.163770   626 device.cpp:197] Added device "Tesla T4" with id "CUDA_Tesla T4_0000:00:04".
# I0414 03:01:49.163942   626 device_impl.cpp:540] Mapped host memory limit set to 9,327,222,784 bytes. (8.69G)
# I0414 03:01:49.289815   626 device_impl.cpp:71] Using AVX2 CPU kernels.
# Fra:1 Mem:8.47M (Peak 10.10M) | Time:00:00.26 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | Cube
# Fra:1 Mem:8.47M (Peak 10.10M) | Time:00:00.26 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | 平面
# Fra:1 Mem:8.47M (Peak 10.10M) | Time:00:00.26 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# graph_id_tag_update: id=OBCube flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OBCube flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OBCube flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OBCube flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OBLight flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OBLight flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OBLight flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OBLight flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OBCamera flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OBCamera flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OBCamera flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OBCamera flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OB平面 flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OB平面 flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OB平面 flags=GEOMETRY source=USER_EDIT
# graph_id_tag_update: id=OB平面 flags=GEOMETRY source=USER_EDIT
# I0414 03:01:49.292119   626 sync.cpp:291] Total time spent synchronizing data: 0.000495911
# Fra:1 Mem:8.33M (Peak 10.10M) | Time:00:00.26 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# I0414 03:01:49.292608   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:49.292660   638 film.cpp:553] Effective scene passes:
# I0414 03:01:49.292677   638 film.cpp:555] - type: combined, name: "Combined", mode: DENOISED, is_written: True
# I0414 03:01:49.292695   638 film.cpp:555] - type: combined, name: "Noisy Image", mode: NOISY, is_written: True
# I0414 03:01:49.292714   638 film.cpp:555] - type: adaptive_aux_buffer, name: "", mode: NOISY, is_written: True
# I0414 03:01:49.292732   638 film.cpp:555] - type: denoising_normal, name: "", mode: NOISY, is_written: True
# I0414 03:01:49.292749   638 film.cpp:555] - type: denoising_albedo, name: "", mode: NOISY, is_written: True
# I0414 03:01:49.292766   638 film.cpp:555] - type: sample_count, name: "", mode: NOISY, is_written: True
# I0414 03:01:49.292805   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# Fra:1 Mem:8.33M (Peak 10.10M) | Time:00:00.26 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# I0414 03:01:49.292850   638 scene.cpp:553] Requested features:
# I0414 03:01:49.292867   638 scene.cpp:554] Use BSDF True
# I0414 03:01:49.292883   638 scene.cpp:555] Use Principled BSDF True
# I0414 03:01:49.292899   638 scene.cpp:557] Use Emission True
# I0414 03:01:49.292914   638 scene.cpp:558] Use Volume False
# I0414 03:01:49.292932   638 scene.cpp:559] Use Hair False
# I0414 03:01:49.292948   638 scene.cpp:560] Use Bump False
# I0414 03:01:49.292963   638 scene.cpp:561] Use Voronoi False
# I0414 03:01:49.292979   638 scene.cpp:563] Use Shader Raytrace False
# I0414 03:01:49.292995   638 scene.cpp:565] Use Transparent False
# I0414 03:01:49.293010   638 scene.cpp:566] Use Denoising True
# I0414 03:01:49.293026   638 scene.cpp:567] Use Path Tracing True
# I0414 03:01:49.293042   638 scene.cpp:569] Use Hair False
# I0414 03:01:49.293058   638 scene.cpp:570] Use Object Motion False
# I0414 03:01:49.293074   638 scene.cpp:572] Use Camera Motion False
# I0414 03:01:49.293090   638 scene.cpp:574] Use Baking False
# I0414 03:01:49.293112   638 scene.cpp:575] Use Subsurface False
# I0414 03:01:49.293128   638 scene.cpp:576] Use Volume False
# I0414 03:01:49.293143   638 scene.cpp:577] Use Patch Evaluation False
# I0414 03:01:49.293159   638 scene.cpp:579] Use Shadow Catcher False
# I0414 03:01:49.293187   638 device_impl.cpp:262] Testing for pre-compiled kernel /content/blender-3.0.1-linux-x64/3.0/scripts/addons/cycles/lib/kernel_sm_75.cubin.
# I0414 03:01:49.293216   638 device_impl.cpp:264] Using precompiled kernel.
# I0414 03:01:49.346273   638 device_impl.cpp:497] Local memory reserved 283,115,520 bytes. (270.00M)
# Fra:1 Mem:8.33M (Peak 21.39M) | Time:00:00.31 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:8.33M (Peak 21.39M) | Time:00:00.31 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Shaders
# I0414 03:01:49.346786   638 svm.cpp:88] Total 7 shaders.
# I0414 03:01:49.347173   638 device_impl.cpp:717] Buffer allocate: __svm_nodes, 1,024 bytes. (1.00K) in device memory
# I0414 03:01:49.347272   638 device_impl.cpp:717] Buffer allocate: __shaders, 224 bytes. (224) in device memory
# I0414 03:01:49.449636   638 svm.cpp:164] Shader manager updated 7 shaders in 0.10285 seconds.
# Fra:1 Mem:8.83M (Peak 21.39M) | Time:00:00.41 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:8.83M (Peak 21.39M) | Time:00:00.41 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:8.83M (Peak 21.39M) | Time:00:00.41 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:8.83M (Peak 21.39M) | Time:00:00.41 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:8.83M (Peak 21.39M) | Time:00:00.41 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects
# I0414 03:01:49.449779   638 object.cpp:636] Total 2 objects.
# ...
# I0414 03:01:52.283390   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.287544   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.25 | Remaining:00:08.00 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1056/4096
# I0414 03:01:52.290632   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.295075   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.26 | Remaining:00:07.86 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1072/4096
# I0414 03:01:52.298215   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.302767   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.27 | Remaining:00:07.72 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1088/4096
# I0414 03:01:52.305877   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.310050   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.28 | Remaining:00:07.59 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1104/4096
# I0414 03:01:52.313134   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.317544   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.28 | Remaining:00:07.46 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1120/4096
# I0414 03:01:52.320680   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.324800   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.29 | Remaining:00:07.34 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1136/4096
# I0414 03:01:52.327889   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.332190   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.30 | Remaining:00:07.21 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1152/4096
# I0414 03:01:52.335274   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.339241   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.31 | Remaining:00:07.09 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1168/4096
# I0414 03:01:52.342331   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.346613   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.31 | Remaining:00:06.98 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1184/4096
# I0414 03:01:52.349699   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.353935   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.32 | Remaining:00:06.87 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1200/4096
# I0414 03:01:52.357017   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.361281   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.33 | Remaining:00:06.76 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1216/4096
# I0414 03:01:52.364372   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.368469   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.34 | Remaining:00:06.65 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1232/4096
# I0414 03:01:52.371578   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.375834   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.34 | Remaining:00:06.54 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1248/4096
# I0414 03:01:52.378917   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.383034   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.35 | Remaining:00:06.44 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1264/4096
# I0414 03:01:52.386116   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.390311   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.36 | Remaining:00:06.34 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1280/4096
# I0414 03:01:52.393390   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.397552   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.36 | Remaining:00:06.24 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1296/4096
# I0414 03:01:52.400652   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.404727   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.37 | Remaining:00:06.14 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1312/4096
# I0414 03:01:52.407887   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.412158   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.38 | Remaining:00:06.05 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1328/4096
# I0414 03:01:52.415275   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.419450   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.39 | Remaining:00:05.96 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1344/4096
# I0414 03:01:52.424167   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.428781   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.40 | Remaining:00:05.87 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1360/4096
# I0414 03:01:52.431886   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.436134   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.40 | Remaining:00:05.79 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1376/4096
# I0414 03:01:52.439247   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.443385   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.41 | Remaining:00:05.70 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1392/4096
# I0414 03:01:52.446497   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.451002   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.42 | Remaining:00:05.62 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1408/4096
# I0414 03:01:52.454103   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.458194   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.42 | Remaining:00:05.53 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1424/4096
# I0414 03:01:52.461293   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.465207   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.43 | Remaining:00:05.45 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1440/4096
# I0414 03:01:52.468299   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.472616   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.44 | Remaining:00:05.37 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1456/4096
# I0414 03:01:52.475703   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.479619   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.45 | Remaining:00:05.29 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1472/4096
# I0414 03:01:52.482702   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.486759   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.45 | Remaining:00:05.22 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1488/4096
# I0414 03:01:52.489856   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.494096   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.46 | Remaining:00:05.14 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1504/4096
# I0414 03:01:52.498219   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.504931   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.47 | Remaining:00:05.08 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1520/4096
# I0414 03:01:52.508075   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.512271   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.48 | Remaining:00:05.00 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1536/4096
# I0414 03:01:52.515372   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.519513   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.49 | Remaining:00:04.93 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1552/4096
# I0414 03:01:52.522600   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.526825   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.49 | Remaining:00:04.86 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1568/4096
# I0414 03:01:52.529934   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.534054   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.50 | Remaining:00:04.80 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1584/4096
# I0414 03:01:52.537166   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.541429   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.51 | Remaining:00:04.73 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1600/4096
# I0414 03:01:52.544529   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.548466   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.52 | Remaining:00:04.66 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1616/4096
# I0414 03:01:52.551582   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.555514   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.52 | Remaining:00:04.60 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1632/4096
# I0414 03:01:52.558589   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.562654   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 163.16M) | Time:00:03.53 | Remaining:00:04.53 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1648/4096
# I0414 03:01:52.565743   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:01:52.569867   638 device_impl.cpp:717] Buffer allocate: num_active_pixels, 4 bytes. (4) in device memory
# Fra:1 Mem:163.15M (Peak 210.61M) | Time:00:19.92 | Remaining:00:28.42 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 1664/4096
# I0414 03:02:08.956679   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# Fra:1 Mem:226.43M (Peak 321.35M) | Time:00:36.24 | Remaining:00:52.28 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Sample 0/4096
# I0414 03:02:25.281031   638 integrator.cpp:346] Cycles adaptive sampling: automatic min samples = 64
# I0414 03:02:25.281062   638 session.cpp:138] Rendering in main loop is done in 35.7709 seconds.
# I0414 03:02:25.281085   638 session.cpp:139]
# Full path tracing report
#
# Path tracing on: Tesla T4 (CUDA) [CUDA_Tesla T4_0000:00:04]
#
# Denoising on: Intel Xeon CPU @ 2.00GHz (CPU) (2 threads) [CPU]
#
# Render Scheduler Summary
#
# Mode: Headless
# Resolution: 1920x1080
#
# Adaptive sampling:
#   Use: True
#   Step: 16
#   Min Samples: 64
#   Threshold: 0.050000
#
# Denoiser:
#   Use: True
#   Type: OpenImageDenoise
#   Start Sample: 0
#   Passes: Color, Albedo, Normal
#
# Time (in seconds):
#                                        Wall              Average
#           Path Tracing             2.739054             0.001646
#        Adaptive Filter             0.311832             0.000188
#               Denoiser            32.553195            16.276597
#         Display Update             0.000005             0.000005
#
#   Total: 35.604086
#
# Rendered 1664 samples in 35.771059 seconds
# Fra:1 Mem:226.43M (Peak 321.35M) | Time:00:36.24 | Remaining:00:52.28 | Mem:472.57M, Peak:472.57M | Scene, ViewLayer | Finished
# I0414 03:02:25.281325   626 session.cpp:467] Total render time: 36.1175
# I0414 03:02:25.281354   626 session.cpp:468] Render time (without synchronization): 35.7712
# Saved: '/drive/MyDrive/blender3d0001.png'
#  Time: 00:37.02 (Saving: 00:00.70)
#
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# graph_id_tag_update: id=SCScene flags=COPY_ON_WRITE source=USER_EDIT
# 	addon_utils.disable io_anim_bvh
# 	addon_utils.disable io_curve_svg
# 	addon_utils.disable io_mesh_ply
# 	addon_utils.disable io_mesh_stl
# 	addon_utils.disable io_mesh_uv_layout
# 	addon_utils.disable io_scene_fbx
# 	addon_utils.disable io_scene_gltf2
# 	addon_utils.disable io_scene_obj
# 	addon_utils.disable io_scene_x3d
# 	addon_utils.disable cycles
# 	addon_utils.disable pose_library
#
# Blender quit
